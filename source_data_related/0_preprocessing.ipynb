# %% [markdown]
# # Preprocessing
# This file is structured to guide through the preprocessing and setup stages required for training a model on a dataset.
#
# ## 1. Preparation
# Our task this step is to change the raw data into several temporal dynamic graphs saved in CSV.
#
# - Download the **Annotations/Activities** from [Drive&Act](https://driveandact.com/), save the file `iccv_activities_3s\activities_3s\kinect_color\objectlevel.chunks_90.csv` and `iccv_activities_3s\activities_3s\kinect_color\tasklevel.chunks_90.csv` in the folder Dataset.
#
# - run this file with the environment `dgb` we create earlier
# - download all the dependency we need, cuda 11.3 is required in advance

# %%
# ! pip install numba transformers
import pandas as pd # type: ignore
import numpy as np
import json
import time

# %% [markdown]
# ## 2. dictionary generation & graph example
# we need to extract the dynamic graph from the raw data. Let's take a brief look at our data.

# %%
df = pd.read_csv('Dataset/objectlevel.chunks_90.csv')

file_ids = df['file_id'].unique()
participant_id = df['participant_id'].unique()
print(f'there are {len(participant_id)} participants, along with {len(file_ids)} videos in the dataset.')


df = df[df['object'] != 'no_object']
display(df)
# Out:
# there are 15 participants, along with 29 videos in the dataset.
#       participant_id                                     file_id  \
# 0                  1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 1                  1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 2                  1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 3                  1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 4                  1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# ...              ...                                         ...
# 9957              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 9959              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 9960              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 9962              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 9963              15  vp15/run2_2018-05-30-13-34-33.kinect_color
#
#       annotation_id  frame_start  frame_end         activity  \
# 0                 0          175        188     reaching_for
# 1                 1          189        208  retracting_from
# 2                 2          208        230      interacting
# 3                 3          240        258     reaching_for
# 4                 4         3011       3031     reaching_for
# ...             ...          ...        ...              ...
# 9957            169        17848      17864     reaching_for
# 9959            172        19035      19052     reaching_for
# 9960            173        19052      19058      interacting
# 9962            175        19360      19371     reaching_for
# 9963            176        19371      19375      interacting
#
#                   object              location  chunk_id
# 0               seatbelt         left_backseat         0
# 1               seatbelt         left_backseat         0
# 2               seatbelt           no_location         0
# 3     multimedia_display  center_console_front         0
# 4      automation_button   center_console_back         0
# ...                  ...                   ...       ...
# 9957  multimedia_display           no_location         0
# 9959  multimedia_display           no_location         0
# 9960  multimedia_display           no_location         0
# 9962   automation_button           no_location         0
# 9963   automation_button           no_location         0
#
# [8717 rows x 9 columns]

# %% [markdown]
# To creat a dynamic graph suitable for further learning, we need to build a table whose head is showon as below:
# | u | v | timestamp | state_label | feature |
# |---|---|-----------|-------------|---------|
# | 1 | 2 | 127       | 0           | 0.27    |
#
# - **u:**            the acvtion generator, usually the participate
# - **v:**            the object operated
# - **timestamp:**:   frame the action happens
# - **stable_label:** stable vector of the edge
# - **feature:**      the weight vector of the edge, here it is the appearance percentage value of the `location` column.
# ### - State
# now we need to extract the state of each nodec from `tasklevel.chunks_90.csv` and print them out

# %%
df_task = pd.read_csv('Dataset/midlevel.chunks_90.csv')

activity_tasks = df_task['activity'].unique()
print(f"there are {len(activity_tasks)} different behaviors")
display(activity_tasks)
# Out:
# there are 39 different behaviors
# array(['standing_by_the_door', 'closing_door_outside',
#        'opening_door_outside', 'entering_car', 'closing_door_inside',
#        'fastening_seat_belt', 'using_multimedia_display', 'sitting_still',
#        'pressing_automation_button', 'fetching_an_object',
#        'opening_laptop', 'working_on_laptop', 'interacting_with_phone',
#        'closing_laptop', 'placing_an_object', 'unfastening_seat_belt',
#        'putting_on_jacket', 'opening_bottle', 'drinking',
#        'closing_bottle', 'looking_or_moving_around (e.g. searching)',
#        'preparing_food', 'eating', 'looking_back_left_shoulder',
#        'taking_off_sunglasses', 'putting_on_sunglasses',
#        'reading_newspaper', 'writing', 'talking_on_phone',
#        'reading_magazine', 'taking_off_jacket', 'opening_door_inside',
#        'exiting_car', 'opening_backpack', 'closing_backpack',
#        'putting_laptop_into_backpack', 'looking_back_right_shoulder',
#        'taking_laptop_from_backpack', 'moving_towards_door'], dtype=object)

# %% [markdown]
# To eusure a efficient and general behavior predicting result, we would like to classify these behaviors into different states

# %%
from transformers import pipeline

classifier = pipeline('zero-shot-classification', model='facebook/bart-large-mnli')

candidate_labels = ('driving ', 'independent','eat or drink','others object concerned')
results = {}
for task in activity_tasks:
    results = classifier(task, candidate_labels)
    results[task] = results['labels'][0]
    print(f'{task} belongs to {results["labels"][0]}')
# Out:
# standing_by_the_door belongs to others object concerned
# closing_door_outside belongs to others object concerned
# opening_door_outside belongs to others object concerned
# entering_car belongs to driving
# closing_door_inside belongs to others object concerned
# fastening_seat_belt belongs to others object concerned
# using_multimedia_display belongs to others object concerned
# sitting_still belongs to independent
# pressing_automation_button belongs to others object concerned
# fetching_an_object belongs to others object concerned
# opening_laptop belongs to others object concerned
# working_on_laptop belongs to others object concerned
# interacting_with_phone belongs to others object concerned
# closing_laptop belongs to others object concerned
# placing_an_object belongs to others object concerned
# unfastening_seat_belt belongs to others object concerned
# putting_on_jacket belongs to others object concerned
# opening_bottle belongs to eat or drink
# drinking belongs to eat or drink
# closing_bottle belongs to others object concerned
# looking_or_moving_around (e.g. searching) belongs to others object concerned
# preparing_food belongs to eat or drink
# eating belongs to eat or drink
# looking_back_left_shoulder belongs to others object concerned
# taking_off_sunglasses belongs to others object concerned
# putting_on_sunglasses belongs to others object concerned
# reading_newspaper belongs to others object concerned
# writing belongs to independent
# talking_on_phone belongs to others object concerned
# reading_magazine belongs to others object concerned
# taking_off_jacket belongs to others object concerned
# opening_door_inside belongs to others object concerned
# exiting_car belongs to others object concerned
# opening_backpack belongs to others object concerned
# closing_backpack belongs to others object concerned
# putting_laptop_into_backpack belongs to others object concerned
# looking_back_right_shoulder belongs to others object concerned
# taking_laptop_from_backpack belongs to others object concerned
# moving_towards_door belongs to others object concerned

# %%
# driving concerned behaviors
state_1 = ['standing_by_the_door', 'closing_door_outside','opening_door_outside', 'entering_car', 'closing_door_inside','fastening_seat_belt', 'moving_towards_door', 'unfastening_seat_belt','opening_door_inside','exiting_car']
# independent behaviors
state_2 = ['sitting_still','looking_or_moving_around (e.g. searching)','looking_back_left_shoulder', 'looking_back_right_shoulder']

# eat or drink concerned behaviors
state_3 = ['preparing_food', 'eating','opening_bottle', 'drinking','closing_bottle',]

# other object concerned behaviors
state_4 = ['using_multimedia_display', 'sitting_still','using_multimedia_display','pressing_automation_button', 'fetching_an_object','opening_laptop', 'working_on_laptop', 'interacting_with_phone','closing_laptop', 'placing_an_object','putting_on_jacket','taking_off_sunglasses', 'putting_on_sunglasses', 'reading_newspaper', 'writing', 'talking_on_phone','reading_magazine', 'taking_off_jacket', 'opening_backpack', 'closing_backpack','putting_laptop_into_backpack','taking_laptop_from_backpack']

df_task['state'] = df_task['activity'].apply(lambda x: 1 if x in state_1 else (2 if x in state_2 else (3 if x in state_3 else (4 if x in state_4 else None))))
df_task['state'] = df_task['state'].astype(int)
display(df_task)
# Out:
#        participant_id                                     file_id  \
# 0                   1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 1                   1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 2                   1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 3                   1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# 4                   1  vp1/run1b_2018-05-29-14-02-47.kinect_color
# ...               ...                                         ...
# 10328              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 10329              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 10330              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 10331              15  vp15/run2_2018-05-30-13-34-33.kinect_color
# 10332              15  vp15/run2_2018-05-30-13-34-33.kinect_color
#
#        annotation_id  frame_start  frame_end               activity  chunk_id  \
# 0                  0           40         58   standing_by_the_door         0
# 1                  1           58         82   closing_door_outside         0
# 2                  2           83        102   standing_by_the_door         0
# 3                  3          102        130   opening_door_outside         0
# 4                  4          130        156           entering_car         0
# ...              ...          ...        ...                    ...       ...
# 10328            125        19595      19604  unfastening_seat_belt         1
# 10329            126        19604      19635    opening_door_inside         0
# 10330            127        19635      19680            exiting_car         0
# 10331            127        19680      19702            exiting_car         1
# 10332            128        19707      19726   closing_door_outside         0
#
#        state
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 10328      1
# 10329      1
# 10330      1
# 10331      1
# 10332      1
#
# [10333 rows x 8 columns]

# %% [markdown]
# ### - Nodes and features
# Here we need to create dictionary for embedded nodes and feature.
# To clearify the process, here we would take the first video as a explain and explain each step resprectively.

# %%
# take the first video as example
filtered_df = df[df['file_id'] == file_ids[0]]
filtered_df_task = df_task[df_task['file_id'] == file_ids[0]]
num_rows = filtered_df.shape[0]
print(f"There are {num_rows} rows in the video {file_ids[0]}.")

# NOTE: Node dictionary
# collection of objects dictinoary
objects = filtered_df['object'].unique()
objects = np.insert(objects, 0, 'participant')
nodes_dict = {object: index for index, object in enumerate(objects)}
print("numerate all the objects included and particitant in the video as well as their index in the nodes dictionary.")
print(nodes_dict)

print("*"*200)

#NOTE: feature dictionary
# collection of locations dictionary
locations = filtered_df['location'].unique()
location_counts = filtered_df['location'].value_counts()
print("the dictionary of locations and their counts percentage in the video.")
location_counts_dict = {location: count for location, count in (location_counts/num_rows).items()}
print(location_counts_dict)
# Out:
# There are 261 rows in the video vp1/run1b_2018-05-29-14-02-47.kinect_color.
# numerate all the objects included and particitant in the video as well as their index in the nodes dictionary.
# {'participant': 0, 'seatbelt': 1, 'multimedia_display': 2, 'automation_button': 3, 'laptop': 4, 'phone': 5, 'jacket': 6, 'bottle': 7, 'food': 8, 'glasses_case': 9, 'glasses': 10, 'newspaper': 11, 'writing_pad': 12, 'magazine': 13}
# ********************************************************************************************************************************************************************************************************
# the dictionary of locations and their counts percentage in the video.
# {'steering_wheel': 0.41762452107279696, 'no_location': 0.16091954022988506, 'lap': 0.1111111111111111, 'center_console_back': 0.09578544061302682, 'center_console_front': 0.0842911877394636, 'codriver_footwell': 0.038314176245210725, 'right_backseat': 0.03065134099616858, 'left_backseat': 0.02681992337164751, 'codriver_seat': 0.019157088122605363, 'driver_door': 0.01532567049808429}

# %% [markdown]
# Now we could build up the new dictionary. Notice that the given data only mark the timestamp with `frame_start` and `frame_end` therefore we should fill the rows in between as well.

# %%
data = {'u': [], 'v': [], 'timestamp': [],'state_label':[],'feature':[]}
graph_df = pd.DataFrame(data)
for index, row in filtered_df.iterrows():

    if row['object'] != 'no_object' :
        # new_row = {'u': 0, 'v': nodes_dict[str(row['object'])], 'timestamp':row['frame_start'],'state_label':0,'feature':location_counts_dict[row['location']]}
        
        frame_start = row['frame_start']
        frame_end = row['frame_end']

        for timestamp in range(frame_start, frame_end+1):
            new_row = {'u': 0, 'v': nodes_dict[str(row['object'])], 'timestamp':timestamp,'state_label':0,'feature':location_counts_dict[row['location']]}
            filtered_tasks = df_task[(df_task['frame_start'] <= timestamp) & (df_task['frame_end'] >= timestamp)]['state'].values
            if len(filtered_tasks) > 0:
                state_label = filtered_tasks[0]
                new_row['state_label'] = state_label
            else:
                new_row['state_label'] = state_label
                print(f"No matching task for timestamp {timestamp},use the former one.")
            graph_df.loc[len(graph_df)] = new_row

    
    pass

graph_df.drop_duplicates(inplace=True)
display(graph_df)
graph_df.to_csv('data4train/graph_data.csv', index=False)
# Out:
#       u  v  timestamp  state_label  feature
# 0     0  1        175            1  0.02682
# 1     0  1        176            1  0.02682
# 2     0  1        177            1  0.02682
# 3     0  1        178            1  0.02682
# 4     0  1        179            1  0.02682
# ...  .. ..        ...          ...      ...
# 9026  0  1      18939            1  0.02682
# 9027  0  1      18940            1  0.02682
# 9028  0  1      18941            1  0.02682
# 9029  0  1      18942            1  0.02682
# 9030  0  1      18943            1  0.02682
#
# [8871 rows x 5 columns]

# %% [markdown]
# ## 3. Graph generation
# Now we could extract the dynamic graph of each video respectively, and save them all in `data4train`.
# The dictionary of features and nodes will be stored in the folder `dict`.

# %%
start_time = time.time()
combined_nodes = {}
combined_features = {}
for count, file_id in enumerate(file_ids):
    filtered_df = df[df['file_id'] == file_id]
    num_rows = filtered_df.shape[0]
    print(f"There are {num_rows} rows in the video {file_id}.")

    # list the state
    filtered_df_task = df_task[df_task['file_id'] == file_id]

    # set name for this graph data
    file_id = file_id.replace('/', '')
    nameid = file_id[:8].replace('b', '').replace('_', '')

    # NOTE: Node dictionary
    # collection of objects dictionary
    objects = filtered_df['object'].unique()
    objects = np.insert(objects, 0, 'participant')
    nodes_dict = {object: index for index, object in enumerate(objects)}
    
    combined_nodes.update({nameid: nodes_dict})

    #NOTE: feature dictionary
    # collection of locations dictionary
    locations = filtered_df['location'].unique()
    location_counts = filtered_df['location'].value_counts()
    location_counts_dict = {location: count for location, count in (location_counts/num_rows).items()}

    combined_features.update({nameid: location_counts_dict})

    data = {'u': [], 'v': [], 'timestamp': [],'state_label':[],'feature':[]}
    graph_df = pd.DataFrame(data)
    for index, row in filtered_df.iterrows():

        if row['object'] != 'no_object' :
            # new_row = {'u': 0, 'v': nodes_dict[str(row['object'])], 'timestamp':row['frame_start'],'state_label':0,'feature':location_counts_dict[row['location']]}
            
            frame_start = row['frame_start']
            frame_end = row['frame_end']

            for timestamp in range(frame_start, frame_end+1):
                new_row = {'u': 0, 'v': nodes_dict[str(row['object'])], 'timestamp':timestamp,'state_label':0,'feature':location_counts_dict[row['location']]}
                filtered_tasks = df_task[(df_task['frame_start'] <= timestamp) & (df_task['frame_end'] >= timestamp)]['state'].values
                if len(filtered_tasks) > 0:
                    state_label = filtered_tasks[0]
                    new_row['state_label'] = state_label
                else:
                    new_row['state_label'] = state_label
                    print(f"No matching task for timestamp {timestamp},use the former one.")
                graph_df.loc[len(graph_df)] = new_row

        
        pass

    graph_df.drop_duplicates(inplace=True)
    directory = 'data4train'
 
    
    
    graph_df.to_csv(f'{directory}/graph_data_{nameid}.csv', index=False)

    print(f"save the graph data of video {file_id} to {directory}/graph_data_{nameid}.csv")

    
    
# Convert dictionaries to JSON strings
combined_nodes_json = json.dumps(combined_nodes)
combined_features_json = json.dumps(combined_features)
# Save JSON strings to text files
with open('dict/combined_nodes.json', 'w') as f:
    f.write(combined_nodes_json)

with open('dict/combined_features.json', 'w') as f:
    f.write(combined_features_json)
print("save the combined nodes and features dictionary to dict/combined_nodes.txt and dict/combined_features.txt")

end_time = time.time()
time_cost = end_time - start_time
print(f"Time cost: {time_cost} seconds")
print('done')
# Out:
# There are 261 rows in the video vp1/run1b_2018-05-29-14-02-47.kinect_color.
# save the graph data of video vp1run1b_2018-05-29-14-02-47.kinect_color to data4train/graph_data_vp1run1.csv
# There are 259 rows in the video vp1/run2_2018-05-29-14-33-44.kinect_color.
# save the graph data of video vp1run2_2018-05-29-14-33-44.kinect_color to data4train/graph_data_vp1run2.csv
# There are 231 rows in the video vp2/run1_2018-05-03-14-08-31.kinect_color.
# save the graph data of video vp2run1_2018-05-03-14-08-31.kinect_color to data4train/graph_data_vp2run1.csv
# There are 337 rows in the video vp2/run2_2018-05-24-17-22-26.kinect_color.
# save the graph data of video vp2run2_2018-05-24-17-22-26.kinect_color to data4train/graph_data_vp2run2.csv
# There are 305 rows in the video vp3/run1b_2018-05-08-08-46-01.kinect_color.
# save the graph data of video vp3run1b_2018-05-08-08-46-01.kinect_color to data4train/graph_data_vp3run1.csv
# There are 222 rows in the video vp3/run2_2018-05-29-16-03-37.kinect_color.
# No matching task for timestamp 2981,use the former one.
# No matching task for timestamp 2982,use the former one.
# No matching task for timestamp 2983,use the former one.
# No matching task for timestamp 2984,use the former one.
# save the graph data of video vp3run2_2018-05-29-16-03-37.kinect_color to data4train/graph_data_vp3run2.csv
# There are 484 rows in the video vp4/run1_2018-05-22-13-28-51.kinect_color.
# No matching task for timestamp 1129,use the former one.
# No matching task for timestamp 1130,use the former one.
# No matching task for timestamp 1131,use the former one.
# No matching task for timestamp 1132,use the former one.
# No matching task for timestamp 1132,use the former one.
# No matching task for timestamp 1133,use the former one.
# No matching task for timestamp 1134,use the former one.
# No matching task for timestamp 1135,use the former one.
# No matching task for timestamp 1136,use the former one.
# No matching task for timestamp 1137,use the former one.
# No matching task for timestamp 1138,use the former one.
# No matching task for timestamp 1139,use the former one.
# No matching task for timestamp 1140,use the former one.
# No matching task for timestamp 1141,use the former one.
# No matching task for timestamp 1142,use the former one.
# No matching task for timestamp 1143,use the former one.
# No matching task for timestamp 1144,use the former one.
# No matching task for timestamp 1145,use the former one.
# No matching task for timestamp 1146,use the former one.
# No matching task for timestamp 1147,use the former one.
# No matching task for timestamp 1148,use the former one.
# No matching task for timestamp 1149,use the former one.
# No matching task for timestamp 1150,use the former one.
# No matching task for timestamp 1151,use the former one.
# No matching task for timestamp 1152,use the former one.
# No matching task for timestamp 1153,use the former one.
# No matching task for timestamp 1154,use the former one.
# No matching task for timestamp 1155,use the former one.
# No matching task for timestamp 1156,use the former one.
# No matching task for timestamp 1157,use the former one.
# No matching task for timestamp 1158,use the former one.
# No matching task for timestamp 1159,use the former one.
# No matching task for timestamp 1160,use the former one.
# No matching task for timestamp 1161,use the former one.
# No matching task for timestamp 1162,use the former one.
# No matching task for timestamp 1184,use the former one.
# No matching task for timestamp 1185,use the former one.
# No matching task for timestamp 1186,use the former one.
# No matching task for timestamp 1187,use the former one.
# No matching task for timestamp 1188,use the former one.
# No matching task for timestamp 1189,use the former one.
# No matching task for timestamp 1190,use the former one.
# No matching task for timestamp 1191,use the former one.
# No matching task for timestamp 1192,use the former one.
# No matching task for timestamp 1193,use the former one.
# No matching task for timestamp 1194,use the former one.
# No matching task for timestamp 1195,use the former one.
# No matching task for timestamp 1196,use the former one.
# No matching task for timestamp 1197,use the former one.
# No matching task for timestamp 1198,use the former one.
# No matching task for timestamp 1199,use the former one.
# No matching task for timestamp 1200,use the former one.
# No matching task for timestamp 1201,use the former one.
# No matching task for timestamp 1202,use the former one.
# No matching task for timestamp 1203,use the former one.
# No matching task for timestamp 1204,use the former one.
# No matching task for timestamp 1205,use the former one.
# No matching task for timestamp 1206,use the former one.
# No matching task for timestamp 1207,use the former one.
# No matching task for timestamp 1208,use the former one.
# No matching task for timestamp 1209,use the former one.
# No matching task for timestamp 1210,use the former one.
# No matching task for timestamp 1211,use the former one.
# No matching task for timestamp 1212,use the former one.
# No matching task for timestamp 1213,use the former one.
# No matching task for timestamp 1214,use the former one.
# No matching task for timestamp 1215,use the former one.
# No matching task for timestamp 1216,use the former one.
# No matching task for timestamp 1217,use the former one.
# No matching task for timestamp 1218,use the former one.
# No matching task for timestamp 1219,use the former one.
# No matching task for timestamp 1220,use the former one.
# No matching task for timestamp 1221,use the former one.
# No matching task for timestamp 1222,use the former one.
# No matching task for timestamp 1222,use the former one.
# No matching task for timestamp 1223,use the former one.
# No matching task for timestamp 1224,use the former one.
# No matching task for timestamp 1225,use the former one.
# No matching task for timestamp 1226,use the former one.
# No matching task for timestamp 1227,use the former one.
# No matching task for timestamp 1228,use the former one.
# No matching task for timestamp 1229,use the former one.
# No matching task for timestamp 1230,use the former one.
# No matching task for timestamp 1231,use the former one.
# No matching task for timestamp 1232,use the former one.
# No matching task for timestamp 1233,use the former one.
# No matching task for timestamp 1234,use the former one.
# No matching task for timestamp 1235,use the former one.
# No matching task for timestamp 1236,use the former one.
# No matching task for timestamp 1237,use the former one.
# No matching task for timestamp 1238,use the former one.
# No matching task for timestamp 1239,use the former one.
# No matching task for timestamp 1240,use the former one.
# No matching task for timestamp 1241,use the former one.
# No matching task for timestamp 1242,use the former one.
# No matching task for timestamp 1243,use the former one.
# No matching task for timestamp 1244,use the former one.
# No matching task for timestamp 1245,use the former one.
# No matching task for timestamp 1246,use the former one.
# No matching task for timestamp 1247,use the former one.
# No matching task for timestamp 1248,use the former one.
# No matching task for timestamp 1249,use the former one.
# No matching task for timestamp 1250,use the former one.
# No matching task for timestamp 1251,use the former one.
# No matching task for timestamp 1252,use the former one.
# No matching task for timestamp 1253,use the former one.
# No matching task for timestamp 1254,use the former one.
# No matching task for timestamp 1255,use the former one.
# No matching task for timestamp 1256,use the former one.
# No matching task for timestamp 1257,use the former one.
# No matching task for timestamp 1258,use the former one.
# No matching task for timestamp 1259,use the former one.
# No matching task for timestamp 1260,use the former one.
# No matching task for timestamp 1261,use the former one.
# No matching task for timestamp 1262,use the former one.
# No matching task for timestamp 1263,use the former one.
# No matching task for timestamp 1264,use the former one.
# No matching task for timestamp 1265,use the former one.
# No matching task for timestamp 1266,use the former one.
# No matching task for timestamp 1267,use the former one.
# No matching task for timestamp 1267,use the former one.
# No matching task for timestamp 1268,use the former one.
# No matching task for timestamp 1269,use the former one.
# No matching task for timestamp 1270,use the former one.
# No matching task for timestamp 1271,use the former one.
# No matching task for timestamp 1272,use the former one.
# No matching task for timestamp 1273,use the former one.
# No matching task for timestamp 1274,use the former one.
# No matching task for timestamp 1275,use the former one.
# No matching task for timestamp 1276,use the former one.
# No matching task for timestamp 1277,use the former one.
# No matching task for timestamp 1278,use the former one.
# No matching task for timestamp 1279,use the former one.
# No matching task for timestamp 1280,use the former one.
# No matching task for timestamp 1281,use the former one.
# No matching task for timestamp 1282,use the former one.
# No matching task for timestamp 1283,use the former one.
# No matching task for timestamp 1284,use the former one.
# No matching task for timestamp 1285,use the former one.
# No matching task for timestamp 1286,use the former one.
# No matching task for timestamp 1287,use the former one.
# No matching task for timestamp 1288,use the former one.
# No matching task for timestamp 1289,use the former one.
# No matching task for timestamp 1290,use the former one.
# No matching task for timestamp 1291,use the former one.
# No matching task for timestamp 1292,use the former one.
# No matching task for timestamp 1293,use the former one.
# No matching task for timestamp 1294,use the former one.
# No matching task for timestamp 1295,use the former one.
# No matching task for timestamp 1296,use the former one.
# No matching task for timestamp 1297,use the former one.
# No matching task for timestamp 1298,use the former one.
# No matching task for timestamp 1299,use the former one.
# No matching task for timestamp 1300,use the former one.
# No matching task for timestamp 1301,use the former one.
# No matching task for timestamp 1302,use the former one.
# No matching task for timestamp 1303,use the former one.
# No matching task for timestamp 1304,use the former one.
# No matching task for timestamp 1305,use the former one.
# No matching task for timestamp 1306,use the former one.
# No matching task for timestamp 1307,use the former one.
# No matching task for timestamp 1308,use the former one.
# No matching task for timestamp 1309,use the former one.
# No matching task for timestamp 1361,use the former one.
# No matching task for timestamp 1362,use the former one.
# No matching task for timestamp 1363,use the former one.
# No matching task for timestamp 1364,use the former one.
# No matching task for timestamp 1365,use the former one.
# No matching task for timestamp 1366,use the former one.
# No matching task for timestamp 1367,use the former one.
# No matching task for timestamp 1368,use the former one.
# No matching task for timestamp 1369,use the former one.
# No matching task for timestamp 1370,use the former one.
# No matching task for timestamp 1370,use the former one.
# No matching task for timestamp 1371,use the former one.
# No matching task for timestamp 1372,use the former one.
# No matching task for timestamp 1373,use the former one.
# No matching task for timestamp 1374,use the former one.
# No matching task for timestamp 1375,use the former one.
# No matching task for timestamp 1376,use the former one.
# No matching task for timestamp 1377,use the former one.
# No matching task for timestamp 1378,use the former one.
# No matching task for timestamp 1379,use the former one.
# No matching task for timestamp 1380,use the former one.
# No matching task for timestamp 1381,use the former one.
# No matching task for timestamp 1382,use the former one.
# No matching task for timestamp 1383,use the former one.
# No matching task for timestamp 1384,use the former one.
# No matching task for timestamp 1385,use the former one.
# No matching task for timestamp 1386,use the former one.
# No matching task for timestamp 1387,use the former one.
# No matching task for timestamp 1672,use the former one.
# No matching task for timestamp 1673,use the former one.
# No matching task for timestamp 1674,use the former one.
# No matching task for timestamp 1675,use the former one.
# No matching task for timestamp 1676,use the former one.
# No matching task for timestamp 1677,use the former one.
# No matching task for timestamp 1678,use the former one.
# No matching task for timestamp 1870,use the former one.
# No matching task for timestamp 1871,use the former one.
# No matching task for timestamp 1872,use the former one.
# No matching task for timestamp 1873,use the former one.
# No matching task for timestamp 1874,use the former one.
# No matching task for timestamp 1875,use the former one.
# No matching task for timestamp 1876,use the former one.
# No matching task for timestamp 1877,use the former one.
# No matching task for timestamp 1877,use the former one.
# No matching task for timestamp 1878,use the former one.
# No matching task for timestamp 1879,use the former one.
# No matching task for timestamp 1880,use the former one.
# No matching task for timestamp 1881,use the former one.
# No matching task for timestamp 1882,use the former one.
# No matching task for timestamp 1883,use the former one.
# No matching task for timestamp 1884,use the former one.
# No matching task for timestamp 1885,use the former one.
# No matching task for timestamp 1886,use the former one.
# No matching task for timestamp 1887,use the former one.
# No matching task for timestamp 1888,use the former one.
# No matching task for timestamp 1889,use the former one.
# No matching task for timestamp 1890,use the former one.
# No matching task for timestamp 1891,use the former one.
# No matching task for timestamp 1892,use the former one.
# No matching task for timestamp 1893,use the former one.
# No matching task for timestamp 1894,use the former one.
# No matching task for timestamp 27100,use the former one.
# No matching task for timestamp 27101,use the former one.
# No matching task for timestamp 27102,use the former one.
# No matching task for timestamp 27103,use the former one.
# No matching task for timestamp 27104,use the former one.
# No matching task for timestamp 27105,use the former one.
# No matching task for timestamp 27106,use the former one.
# No matching task for timestamp 27107,use the former one.
# No matching task for timestamp 27108,use the former one.
# No matching task for timestamp 27109,use the former one.
# No matching task for timestamp 27588,use the former one.
# No matching task for timestamp 27589,use the former one.
# No matching task for timestamp 27590,use the former one.
# No matching task for timestamp 27591,use the former one.
# No matching task for timestamp 27592,use the former one.
# No matching task for timestamp 27593,use the former one.
# No matching task for timestamp 27594,use the former one.
# No matching task for timestamp 27595,use the former one.
# No matching task for timestamp 27596,use the former one.
# No matching task for timestamp 27597,use the former one.
# No matching task for timestamp 27598,use the former one.
# No matching task for timestamp 27599,use the former one.
# No matching task for timestamp 27776,use the former one.
# No matching task for timestamp 27777,use the former one.
# No matching task for timestamp 27778,use the former one.
# No matching task for timestamp 27779,use the former one.
# No matching task for timestamp 27780,use the former one.
# No matching task for timestamp 27781,use the former one.
# No matching task for timestamp 27782,use the former one.
# No matching task for timestamp 27783,use the former one.
# No matching task for timestamp 27784,use the former one.
# No matching task for timestamp 28099,use the former one.
# No matching task for timestamp 28100,use the former one.
# No matching task for timestamp 28101,use the former one.
# No matching task for timestamp 28102,use the former one.
# No matching task for timestamp 28103,use the former one.
# No matching task for timestamp 28104,use the former one.
# No matching task for timestamp 28105,use the former one.
# No matching task for timestamp 28106,use the former one.
# No matching task for timestamp 28107,use the former one.
# No matching task for timestamp 28108,use the former one.
# No matching task for timestamp 28109,use the former one.
# No matching task for timestamp 28224,use the former one.
# No matching task for timestamp 28225,use the former one.
# No matching task for timestamp 28226,use the former one.
# No matching task for timestamp 29910,use the former one.
# No matching task for timestamp 29911,use the former one.
# No matching task for timestamp 29912,use the former one.
# No matching task for timestamp 29913,use the former one.
# No matching task for timestamp 29914,use the former one.
# No matching task for timestamp 29915,use the former one.
# No matching task for timestamp 29916,use the former one.
# No matching task for timestamp 29917,use the former one.
# No matching task for timestamp 29918,use the former one.
# No matching task for timestamp 29919,use the former one.
# No matching task for timestamp 29920,use the former one.
# No matching task for timestamp 29921,use the former one.
# No matching task for timestamp 29922,use the former one.
# No matching task for timestamp 29923,use the former one.
# No matching task for timestamp 29924,use the former one.
# No matching task for timestamp 29925,use the former one.
# No matching task for timestamp 29929,use the former one.
# No matching task for timestamp 29930,use the former one.
# No matching task for timestamp 29931,use the former one.
# No matching task for timestamp 29931,use the former one.
# No matching task for timestamp 29932,use the former one.
# No matching task for timestamp 29933,use the former one.
# No matching task for timestamp 29934,use the former one.
# No matching task for timestamp 29935,use the former one.
# No matching task for timestamp 29936,use the former one.
# No matching task for timestamp 29937,use the former one.
# No matching task for timestamp 29938,use the former one.
# No matching task for timestamp 29939,use the former one.
# No matching task for timestamp 29940,use the former one.
# No matching task for timestamp 29941,use the former one.
# No matching task for timestamp 29942,use the former one.
# No matching task for timestamp 29943,use the former one.
# No matching task for timestamp 29944,use the former one.
# No matching task for timestamp 29945,use the former one.
# No matching task for timestamp 29946,use the former one.
# No matching task for timestamp 29947,use the former one.
# No matching task for timestamp 29948,use the former one.
# No matching task for timestamp 29949,use the former one.
# No matching task for timestamp 29950,use the former one.
# No matching task for timestamp 29951,use the former one.
# No matching task for timestamp 29952,use the former one.
# No matching task for timestamp 29953,use the former one.
# No matching task for timestamp 29954,use the former one.
# No matching task for timestamp 29955,use the former one.
# No matching task for timestamp 29956,use the former one.
# No matching task for timestamp 29957,use the former one.
# No matching task for timestamp 29958,use the former one.
# No matching task for timestamp 29959,use the former one.
# No matching task for timestamp 29960,use the former one.
# No matching task for timestamp 29961,use the former one.
# No matching task for timestamp 29962,use the former one.
# No matching task for timestamp 29963,use the former one.
# No matching task for timestamp 29964,use the former one.
# No matching task for timestamp 29965,use the former one.
# No matching task for timestamp 29966,use the former one.
# No matching task for timestamp 29967,use the former one.
# No matching task for timestamp 29968,use the former one.
# No matching task for timestamp 29969,use the former one.
# No matching task for timestamp 29970,use the former one.
# No matching task for timestamp 29971,use the former one.
# No matching task for timestamp 29972,use the former one.
# No matching task for timestamp 29973,use the former one.
# No matching task for timestamp 29974,use the former one.
# No matching task for timestamp 29975,use the former one.
# No matching task for timestamp 29976,use the former one.
# No matching task for timestamp 29976,use the former one.
# No matching task for timestamp 29977,use the former one.
# No matching task for timestamp 29978,use the former one.
# No matching task for timestamp 29979,use the former one.
# No matching task for timestamp 29980,use the former one.
# No matching task for timestamp 30392,use the former one.
# No matching task for timestamp 30393,use the former one.
# No matching task for timestamp 30394,use the former one.
# No matching task for timestamp 30395,use the former one.
# No matching task for timestamp 30396,use the former one.
# No matching task for timestamp 30397,use the former one.
# No matching task for timestamp 30398,use the former one.
# No matching task for timestamp 30399,use the former one.
# No matching task for timestamp 30400,use the former one.
# No matching task for timestamp 30401,use the former one.
# No matching task for timestamp 30402,use the former one.
# No matching task for timestamp 30403,use the former one.
# No matching task for timestamp 30404,use the former one.
# No matching task for timestamp 30405,use the former one.
# No matching task for timestamp 30406,use the former one.
# No matching task for timestamp 30407,use the former one.
# No matching task for timestamp 30408,use the former one.
# No matching task for timestamp 30409,use the former one.
# No matching task for timestamp 30410,use the former one.
# No matching task for timestamp 30411,use the former one.
# No matching task for timestamp 30412,use the former one.
# No matching task for timestamp 30413,use the former one.
# No matching task for timestamp 30414,use the former one.
# No matching task for timestamp 30415,use the former one.
# No matching task for timestamp 30416,use the former one.
# No matching task for timestamp 30416,use the former one.
# No matching task for timestamp 30417,use the former one.
# No matching task for timestamp 30418,use the former one.
# No matching task for timestamp 30419,use the former one.
# No matching task for timestamp 30420,use the former one.
# No matching task for timestamp 30421,use the former one.
# No matching task for timestamp 30422,use the former one.
# No matching task for timestamp 30423,use the former one.
# No matching task for timestamp 30424,use the former one.
# No matching task for timestamp 30425,use the former one.
# No matching task for timestamp 30426,use the former one.
# No matching task for timestamp 31734,use the former one.
# No matching task for timestamp 31735,use the former one.
# No matching task for timestamp 31736,use the former one.
# No matching task for timestamp 31737,use the former one.
# No matching task for timestamp 31738,use the former one.
# No matching task for timestamp 31739,use the former one.
# No matching task for timestamp 31740,use the former one.
# No matching task for timestamp 31741,use the former one.
# No matching task for timestamp 31742,use the former one.
# No matching task for timestamp 31743,use the former one.
# No matching task for timestamp 31744,use the former one.
# No matching task for timestamp 31745,use the former one.
# No matching task for timestamp 32773,use the former one.
# No matching task for timestamp 32774,use the former one.
# No matching task for timestamp 32775,use the former one.
# No matching task for timestamp 32776,use the former one.
# No matching task for timestamp 32777,use the former one.
# No matching task for timestamp 32778,use the former one.
# No matching task for timestamp 32779,use the former one.
# No matching task for timestamp 32780,use the former one.
# No matching task for timestamp 32781,use the former one.
# No matching task for timestamp 32782,use the former one.
# No matching task for timestamp 32783,use the former one.
# No matching task for timestamp 32784,use the former one.
# No matching task for timestamp 32785,use the former one.
# No matching task for timestamp 32786,use the former one.
# No matching task for timestamp 32787,use the former one.
# No matching task for timestamp 32788,use the former one.
# No matching task for timestamp 32789,use the former one.
# No matching task for timestamp 32790,use the former one.
# No matching task for timestamp 32791,use the former one.
# No matching task for timestamp 32792,use the former one.
# No matching task for timestamp 32833,use the former one.
# No matching task for timestamp 32834,use the former one.
# No matching task for timestamp 32835,use the former one.
# No matching task for timestamp 32836,use the former one.
# No matching task for timestamp 32837,use the former one.
# No matching task for timestamp 32838,use the former one.
# No matching task for timestamp 32838,use the former one.
# No matching task for timestamp 32839,use the former one.
# No matching task for timestamp 32840,use the former one.
# No matching task for timestamp 32841,use the former one.
# No matching task for timestamp 32842,use the former one.
# No matching task for timestamp 32843,use the former one.
# No matching task for timestamp 32844,use the former one.
# No matching task for timestamp 32845,use the former one.
# No matching task for timestamp 32846,use the former one.
# No matching task for timestamp 32847,use the former one.
# No matching task for timestamp 32848,use the former one.
# No matching task for timestamp 32849,use the former one.
# No matching task for timestamp 32850,use the former one.
# No matching task for timestamp 32851,use the former one.
# No matching task for timestamp 32852,use the former one.
# No matching task for timestamp 32853,use the former one.
# No matching task for timestamp 32854,use the former one.
# No matching task for timestamp 32855,use the former one.
# No matching task for timestamp 32856,use the former one.
# No matching task for timestamp 32857,use the former one.
# No matching task for timestamp 32858,use the former one.
# No matching task for timestamp 32859,use the former one.
# No matching task for timestamp 32860,use the former one.
# No matching task for timestamp 32861,use the former one.
# No matching task for timestamp 32862,use the former one.
# No matching task for timestamp 32863,use the former one.
# No matching task for timestamp 32864,use the former one.
# No matching task for timestamp 32865,use the former one.
# No matching task for timestamp 32866,use the former one.
# No matching task for timestamp 32867,use the former one.
# No matching task for timestamp 32868,use the former one.
# No matching task for timestamp 32917,use the former one.
# No matching task for timestamp 32918,use the former one.
# No matching task for timestamp 32919,use the former one.
# No matching task for timestamp 32920,use the former one.
# No matching task for timestamp 32921,use the former one.
# No matching task for timestamp 32922,use the former one.
# No matching task for timestamp 32923,use the former one.
# No matching task for timestamp 32924,use the former one.
# No matching task for timestamp 32925,use the former one.
# No matching task for timestamp 32926,use the former one.
# No matching task for timestamp 32927,use the former one.
# No matching task for timestamp 32928,use the former one.
# No matching task for timestamp 32929,use the former one.
# No matching task for timestamp 32930,use the former one.
# No matching task for timestamp 32931,use the former one.
# No matching task for timestamp 32932,use the former one.
# No matching task for timestamp 32933,use the former one.
# No matching task for timestamp 32934,use the former one.
# No matching task for timestamp 32935,use the former one.
# No matching task for timestamp 32936,use the former one.
# No matching task for timestamp 32937,use the former one.
# No matching task for timestamp 32938,use the former one.
# No matching task for timestamp 32988,use the former one.
# No matching task for timestamp 32989,use the former one.
# No matching task for timestamp 32990,use the former one.
# No matching task for timestamp 32991,use the former one.
# No matching task for timestamp 32992,use the former one.
# No matching task for timestamp 32993,use the former one.
# No matching task for timestamp 32994,use the former one.
# No matching task for timestamp 32995,use the former one.
# save the graph data of video vp4run1_2018-05-22-13-28-51.kinect_color to data4train/graph_data_vp4run1.csv
# There are 281 rows in the video vp4/run2_2018-05-22-14-25-04.kinect_color.
# No matching task for timestamp 27081,use the former one.
# No matching task for timestamp 27082,use the former one.
# No matching task for timestamp 27083,use the former one.
# No matching task for timestamp 27084,use the former one.
# No matching task for timestamp 27085,use the former one.
# No matching task for timestamp 27086,use the former one.
# No matching task for timestamp 27087,use the former one.
# No matching task for timestamp 27088,use the former one.
# save the graph data of video vp4run2_2018-05-22-14-25-04.kinect_color to data4train/graph_data_vp4run2.csv
# There are 414 rows in the video vp5/run1_2018-05-22-15-10-41.kinect_color.
# No matching task for timestamp 1116,use the former one.
# No matching task for timestamp 1117,use the former one.
# No matching task for timestamp 1118,use the former one.
# save the graph data of video vp5run1_2018-05-22-15-10-41.kinect_color to data4train/graph_data_vp5run1.csv
# There are 255 rows in the video vp5/run2b_2018-05-22-15-50-07.kinect_color.
# save the graph data of video vp5run2b_2018-05-22-15-50-07.kinect_color to data4train/graph_data_vp5run2.csv
# There are 306 rows in the video vp6/run1_2018-05-23-10-21-45.kinect_color.
# No matching task for timestamp 1540,use the former one.
# No matching task for timestamp 1541,use the former one.
# No matching task for timestamp 1542,use the former one.
# No matching task for timestamp 1543,use the former one.
# No matching task for timestamp 1544,use the former one.
# No matching task for timestamp 1545,use the former one.
# No matching task for timestamp 1546,use the former one.
# No matching task for timestamp 1547,use the former one.
# No matching task for timestamp 1548,use the former one.
# No matching task for timestamp 1549,use the former one.
# save the graph data of video vp6run1_2018-05-23-10-21-45.kinect_color to data4train/graph_data_vp6run1.csv
# There are 251 rows in the video vp6/run2_2018-05-23-11-05-00.kinect_color.
# save the graph data of video vp6run2_2018-05-23-11-05-00.kinect_color to data4train/graph_data_vp6run2.csv
# There are 305 rows in the video vp7/run1_2018-05-23-13-16-52.kinect_color.
# save the graph data of video vp7run1_2018-05-23-13-16-52.kinect_color to data4train/graph_data_vp7run1.csv
# There are 194 rows in the video vp7/run2b_2018-05-23-13-54-07.kinect_color.
# save the graph data of video vp7run2b_2018-05-23-13-54-07.kinect_color to data4train/graph_data_vp7run2.csv
# There are 347 rows in the video vp8/run1d_2018-05-23-14-54-38.kinect_color.
# save the graph data of video vp8run1d_2018-05-23-14-54-38.kinect_color to data4train/graph_data_vp8run1d.csv
# There are 303 rows in the video vp8/run2_2018-05-23-15-30-27.kinect_color.
# save the graph data of video vp8run2_2018-05-23-15-30-27.kinect_color to data4train/graph_data_vp8run2.csv
# There are 289 rows in the video vp9/run1b_2018-05-23-16-19-17.kinect_color.
# save the graph data of video vp9run1b_2018-05-23-16-19-17.kinect_color to data4train/graph_data_vp9run1.csv
# There are 337 rows in the video vp10/run1_2018-05-24-13-14-41.kinect_color.
# No matching task for timestamp 1153,use the former one.
# No matching task for timestamp 1154,use the former one.
# No matching task for timestamp 1155,use the former one.
# No matching task for timestamp 1156,use the former one.
# No matching task for timestamp 1157,use the former one.
# No matching task for timestamp 1158,use the former one.
# No matching task for timestamp 1159,use the former one.
# No matching task for timestamp 1160,use the former one.
# No matching task for timestamp 1161,use the former one.
# No matching task for timestamp 1162,use the former one.
# No matching task for timestamp 1248,use the former one.
# No matching task for timestamp 1249,use the former one.
# No matching task for timestamp 1250,use the former one.
# No matching task for timestamp 1251,use the former one.
# No matching task for timestamp 1252,use the former one.
# No matching task for timestamp 1253,use the former one.
# No matching task for timestamp 1254,use the former one.
# No matching task for timestamp 1255,use the former one.
# save the graph data of video vp10run1_2018-05-24-13-14-41.kinect_color to data4train/graph_data_vp10run1.csv
# There are 269 rows in the video vp10/run2_2018-05-24-14-08-46.kinect_color.
# save the graph data of video vp10run2_2018-05-24-14-08-46.kinect_color to data4train/graph_data_vp10run2.csv
# There are 279 rows in the video vp11/run1_2018-05-24-13-44-01.kinect_color.
# save the graph data of video vp11run1_2018-05-24-13-44-01.kinect_color to data4train/graph_data_vp11run1.csv
# There are 244 rows in the video vp11/run2_2018-05-24-14-35-56.kinect_color.
# No matching task for timestamp 2975,use the former one.
# No matching task for timestamp 2976,use the former one.
# No matching task for timestamp 2977,use the former one.
# No matching task for timestamp 2978,use the former one.
# No matching task for timestamp 2979,use the former one.
# No matching task for timestamp 2980,use the former one.
# No matching task for timestamp 2981,use the former one.
# No matching task for timestamp 2982,use the former one.
# No matching task for timestamp 2983,use the former one.
# No matching task for timestamp 2984,use the former one.
# save the graph data of video vp11run2_2018-05-24-14-35-56.kinect_color to data4train/graph_data_vp11run2.csv
# There are 306 rows in the video vp12/run1_2018-05-24-15-44-28.kinect_color.
# No matching task for timestamp 870,use the former one.
# No matching task for timestamp 871,use the former one.
# No matching task for timestamp 872,use the former one.
# No matching task for timestamp 873,use the former one.
# No matching task for timestamp 874,use the former one.
# No matching task for timestamp 875,use the former one.
# No matching task for timestamp 876,use the former one.
# No matching task for timestamp 877,use the former one.
# save the graph data of video vp12run1_2018-05-24-15-44-28.kinect_color to data4train/graph_data_vp12run1.csv
# There are 414 rows in the video vp12/run2_2018-05-24-16-21-35.kinect_color.
# save the graph data of video vp12run2_2018-05-24-16-21-35.kinect_color to data4train/graph_data_vp12run2.csv
# There are 278 rows in the video vp13/run1_2018-05-29-15-21-10.kinect_color.
# save the graph data of video vp13run1_2018-05-29-15-21-10.kinect_color to data4train/graph_data_vp13run1.csv
# There are 244 rows in the video vp13/run2_2018-05-30-11-34-54.kinect_color.
# save the graph data of video vp13run2_2018-05-30-11-34-54.kinect_color to data4train/graph_data_vp13run2.csv
# There are 426 rows in the video vp14/run1_2018-05-30-10-11-09.kinect_color.
# save the graph data of video vp14run1_2018-05-30-10-11-09.kinect_color to data4train/graph_data_vp14run1.csv
# There are 392 rows in the video vp14/run2_2018-05-30-10-42-33.kinect_color.
# save the graph data of video vp14run2_2018-05-30-10-42-33.kinect_color to data4train/graph_data_vp14run2.csv
# There are 236 rows in the video vp15/run1_2018-05-30-13-05-35.kinect_color.
# No matching task for timestamp 967,use the former one.
# No matching task for timestamp 968,use the former one.
# No matching task for timestamp 969,use the former one.
# No matching task for timestamp 970,use the former one.
# No matching task for timestamp 971,use the former one.
# No matching task for timestamp 972,use the former one.
# No matching task for timestamp 973,use the former one.
# save the graph data of video vp15run1_2018-05-30-13-05-35.kinect_color to data4train/graph_data_vp15run1.csv
# There are 248 rows in the video vp15/run2_2018-05-30-13-34-33.kinect_color.
# save the graph data of video vp15run2_2018-05-30-13-34-33.kinect_color to data4train/graph_data_vp15run2.csv
# save the combined nodes and features dictionary to dict/combined_nodes.txt and dict/combined_features.txt
# Time cost: 240.30604457855225 seconds
# done

# %% [markdown]
# here is the command to search for the dictionary of specific graph

# %%
# with open("combined_nodes.json", "r") as f:
#     combined_nodes = combined_nodes.load(f)
# with open("combined_features.json", "r") as f:
#     combined_nodes = combined_features.load(f)

inquired_file_id =  "vp2run2"

print(f"the nodes dictionary of video {inquired_file_id} is:")
print(combined_nodes[inquired_file_id])
print(f"the features dictionary of video {inquired_file_id} is:")
print(combined_features[inquired_file_id])
# Out:
# the nodes dictionary of video vp2run2 is:
# {'participant': 0, 'seatbelt': 1, 'gearstick': 2, 'automation_button': 3, 'multimedia_display': 4, 'newspaper': 5, 'writing_pad': 6, 'pen': 7, 'magazine': 8, 'jacket': 9, 'food': 10, 'bottle': 11, 'laptop': 12, 'phone': 13}
# the features dictionary of video vp2run2 is:
# {'front_area': 0.4629080118694362, 'no_location': 0.20474777448071216, 'lap': 0.08902077151335312, 'steering_wheel': 0.08605341246290801, 'head': 0.05637982195845697, 'codriver_seat': 0.04747774480712166, 'center_console_back': 0.020771513353115726, 'trouser_pocket': 0.017804154302670624, 'right_backseat': 0.01483679525222552}

# %% [markdown]
# here we would also generate a graph with all the participants as comparasion

# %%
start_time = time.time()
nodes_participants = {}
nodes_objects = {}
features = {}
# for count, file_id in enumerate(file_ids):

num_rows = df.shape[0]
print(f"There are {num_rows} rows here.")

# # set name for this graph data
# file_id = file_id.replace('/', '')
# nameid = file_id[:8].replace('b', '').replace('_', '')

# NOTE: Node dictionary
# collection of objects dictionary
nodes_objects = df['object'].unique()
nodes_obj_dict = {object: index + 100 for index, object in enumerate(nodes_objects)}
print(nodes_obj_dict)


#NOTE: feature dictionary
# collection of locations dictionary
locations = df['location'].unique()
location_counts = df['location'].value_counts()
location_counts_dict = {location: count for location, count in (location_counts/num_rows).items()}
print(location_counts_dict)


data = {'u': [], 'v': [], 'timestamp': [],'state_label':[],'feature':[]}
graph_df = pd.DataFrame(data)
for index, row in df.iterrows():

    if row['object'] != 'no_object' :
        
        frame_start = row['frame_start']
        frame_end = row['frame_end']

        for timestamp in range(frame_start, frame_end+1):
            new_row = {'u': row['participant_id'], 'v': nodes_obj_dict[str(row['object'])], 'timestamp':timestamp,'state_label':0,'feature':location_counts_dict[row['location']]}
            filtered_tasks = df_task[(df_task['frame_start'] <= timestamp) & (df_task['frame_end'] >= timestamp)]['state'].values
            if len(filtered_tasks) > 0:
                state_label = filtered_tasks[0]
                new_row['state_label'] = state_label
            else:
                new_row['state_label'] = state_label
                print(f"No matching task for timestamp {timestamp},use the former one.")
            graph_df.loc[len(graph_df)] = new_row

    
    pass
directory = 'data4train'
 
graph_df = graph_df.sort_values('timestamp')
    
graph_df.to_csv(f'{directory}/graph_data_combined.csv', index=False)

display(graph_df)

print(f"save the graph data of all participants to {directory}/graph_data_combined.csv")

    
    
# Convert dictionaries to JSON strings
with open('dict/nodes.json', 'w') as f:
    f.write(json.dumps(nodes_obj_dict))

with open('dict/features.json', 'w') as f:
    f.write(json.dumps(location_counts_dict))
print("save the combined nodes and features dictionary to dict/nodes.txt and dict/features.txt")

end_time = time.time()
time_cost = end_time - start_time
print(f"Time cost: {time_cost} seconds")
print('done')
# Out:
# There are 8717 rows here.
# {'seatbelt': 100, 'multimedia_display': 101, 'automation_button': 102, 'laptop': 103, 'phone': 104, 'jacket': 105, 'bottle': 106, 'food': 107, 'glasses_case': 108, 'glasses': 109, 'newspaper': 110, 'writing_pad': 111, 'magazine': 112, 'gearstick': 113, 'pen': 114, 'backpack': 115}
# {'front_area': 0.37765286222324196, 'no_location': 0.2258804634622003, 'codriver_seat': 0.09292187679247448, 'steering_wheel': 0.07491109326603189, 'lap': 0.06103017093036595, 'head': 0.055408970976253295, 'center_console_back': 0.033038889526213144, 'codriver_footwell': 0.020075714121830904, 'center_console_front': 0.018584375358494894, 'right_backseat': 0.017207754961569347, 'driver_door': 0.00986577951129976, 'left_backseat': 0.005506481587702191, 'codriver_door': 0.005047608122060342, 'trouser_pocket': 0.0028679591602615577}
# No matching task for timestamp 2981,use the former one.
# No matching task for timestamp 2982,use the former one.
# No matching task for timestamp 2983,use the former one.
# No matching task for timestamp 2984,use the former one.
# No matching task for timestamp 1129,use the former one.
# No matching task for timestamp 1130,use the former one.
# No matching task for timestamp 1131,use the former one.
# No matching task for timestamp 1132,use the former one.
# No matching task for timestamp 1132,use the former one.
# No matching task for timestamp 1133,use the former one.
# No matching task for timestamp 1134,use the former one.
# No matching task for timestamp 1135,use the former one.
# No matching task for timestamp 1136,use the former one.
# No matching task for timestamp 1137,use the former one.
# No matching task for timestamp 1138,use the former one.
# No matching task for timestamp 1139,use the former one.
# No matching task for timestamp 1140,use the former one.
# No matching task for timestamp 1141,use the former one.
# No matching task for timestamp 1142,use the former one.
# No matching task for timestamp 1143,use the former one.
# No matching task for timestamp 1144,use the former one.
# No matching task for timestamp 1145,use the former one.
# No matching task for timestamp 1146,use the former one.
# No matching task for timestamp 1147,use the former one.
# No matching task for timestamp 1148,use the former one.
# No matching task for timestamp 1149,use the former one.
# No matching task for timestamp 1150,use the former one.
# No matching task for timestamp 1151,use the former one.
# No matching task for timestamp 1152,use the former one.
# No matching task for timestamp 1153,use the former one.
# No matching task for timestamp 1154,use the former one.
# No matching task for timestamp 1155,use the former one.
# No matching task for timestamp 1156,use the former one.
# No matching task for timestamp 1157,use the former one.
# No matching task for timestamp 1158,use the former one.
# No matching task for timestamp 1159,use the former one.
# No matching task for timestamp 1160,use the former one.
# No matching task for timestamp 1161,use the former one.
# No matching task for timestamp 1162,use the former one.
# No matching task for timestamp 1184,use the former one.
# No matching task for timestamp 1185,use the former one.
# No matching task for timestamp 1186,use the former one.
# No matching task for timestamp 1187,use the former one.
# No matching task for timestamp 1188,use the former one.
# No matching task for timestamp 1189,use the former one.
# No matching task for timestamp 1190,use the former one.
# No matching task for timestamp 1191,use the former one.
# No matching task for timestamp 1192,use the former one.
# No matching task for timestamp 1193,use the former one.
# No matching task for timestamp 1194,use the former one.
# No matching task for timestamp 1195,use the former one.
# No matching task for timestamp 1196,use the former one.
# No matching task for timestamp 1197,use the former one.
# No matching task for timestamp 1198,use the former one.
# No matching task for timestamp 1199,use the former one.
# No matching task for timestamp 1200,use the former one.
# No matching task for timestamp 1201,use the former one.
# No matching task for timestamp 1202,use the former one.
# No matching task for timestamp 1203,use the former one.
# No matching task for timestamp 1204,use the former one.
# No matching task for timestamp 1205,use the former one.
# No matching task for timestamp 1206,use the former one.
# No matching task for timestamp 1207,use the former one.
# No matching task for timestamp 1208,use the former one.
# No matching task for timestamp 1209,use the former one.
# No matching task for timestamp 1210,use the former one.
# No matching task for timestamp 1211,use the former one.
# No matching task for timestamp 1212,use the former one.
# No matching task for timestamp 1213,use the former one.
# No matching task for timestamp 1214,use the former one.
# No matching task for timestamp 1215,use the former one.
# No matching task for timestamp 1216,use the former one.
# No matching task for timestamp 1217,use the former one.
# No matching task for timestamp 1218,use the former one.
# No matching task for timestamp 1219,use the former one.
# No matching task for timestamp 1220,use the former one.
# No matching task for timestamp 1221,use the former one.
# No matching task for timestamp 1222,use the former one.
# No matching task for timestamp 1222,use the former one.
# No matching task for timestamp 1223,use the former one.
# No matching task for timestamp 1224,use the former one.
# No matching task for timestamp 1225,use the former one.
# No matching task for timestamp 1226,use the former one.
# No matching task for timestamp 1227,use the former one.
# No matching task for timestamp 1228,use the former one.
# No matching task for timestamp 1229,use the former one.
# No matching task for timestamp 1230,use the former one.
# No matching task for timestamp 1231,use the former one.
# No matching task for timestamp 1232,use the former one.
# No matching task for timestamp 1233,use the former one.
# No matching task for timestamp 1234,use the former one.
# No matching task for timestamp 1235,use the former one.
# No matching task for timestamp 1236,use the former one.
# No matching task for timestamp 1237,use the former one.
# No matching task for timestamp 1238,use the former one.
# No matching task for timestamp 1239,use the former one.
# No matching task for timestamp 1240,use the former one.
# No matching task for timestamp 1241,use the former one.
# No matching task for timestamp 1242,use the former one.
# No matching task for timestamp 1243,use the former one.
# No matching task for timestamp 1244,use the former one.
# No matching task for timestamp 1245,use the former one.
# No matching task for timestamp 1246,use the former one.
# No matching task for timestamp 1247,use the former one.
# No matching task for timestamp 1248,use the former one.
# No matching task for timestamp 1249,use the former one.
# No matching task for timestamp 1250,use the former one.
# No matching task for timestamp 1251,use the former one.
# No matching task for timestamp 1252,use the former one.
# No matching task for timestamp 1253,use the former one.
# No matching task for timestamp 1254,use the former one.
# No matching task for timestamp 1255,use the former one.
# No matching task for timestamp 1256,use the former one.
# No matching task for timestamp 1257,use the former one.
# No matching task for timestamp 1258,use the former one.
# No matching task for timestamp 1259,use the former one.
# No matching task for timestamp 1260,use the former one.
# No matching task for timestamp 1261,use the former one.
# No matching task for timestamp 1262,use the former one.
# No matching task for timestamp 1263,use the former one.
# No matching task for timestamp 1264,use the former one.
# No matching task for timestamp 1265,use the former one.
# No matching task for timestamp 1266,use the former one.
# No matching task for timestamp 1267,use the former one.
# No matching task for timestamp 1267,use the former one.
# No matching task for timestamp 1268,use the former one.
# No matching task for timestamp 1269,use the former one.
# No matching task for timestamp 1270,use the former one.
# No matching task for timestamp 1271,use the former one.
# No matching task for timestamp 1272,use the former one.
# No matching task for timestamp 1273,use the former one.
# No matching task for timestamp 1274,use the former one.
# No matching task for timestamp 1275,use the former one.
# No matching task for timestamp 1276,use the former one.
# No matching task for timestamp 1277,use the former one.
# No matching task for timestamp 1278,use the former one.
# No matching task for timestamp 1279,use the former one.
# No matching task for timestamp 1280,use the former one.
# No matching task for timestamp 1281,use the former one.
# No matching task for timestamp 1282,use the former one.
# No matching task for timestamp 1283,use the former one.
# No matching task for timestamp 1284,use the former one.
# No matching task for timestamp 1285,use the former one.
# No matching task for timestamp 1286,use the former one.
# No matching task for timestamp 1287,use the former one.
# No matching task for timestamp 1288,use the former one.
# No matching task for timestamp 1289,use the former one.
# No matching task for timestamp 1290,use the former one.
# No matching task for timestamp 1291,use the former one.
# No matching task for timestamp 1292,use the former one.
# No matching task for timestamp 1293,use the former one.
# No matching task for timestamp 1294,use the former one.
# No matching task for timestamp 1295,use the former one.
# No matching task for timestamp 1296,use the former one.
# No matching task for timestamp 1297,use the former one.
# No matching task for timestamp 1298,use the former one.
# No matching task for timestamp 1299,use the former one.
# No matching task for timestamp 1300,use the former one.
# No matching task for timestamp 1301,use the former one.
# No matching task for timestamp 1302,use the former one.
# No matching task for timestamp 1303,use the former one.
# No matching task for timestamp 1304,use the former one.
# No matching task for timestamp 1305,use the former one.
# No matching task for timestamp 1306,use the former one.
# No matching task for timestamp 1307,use the former one.
# No matching task for timestamp 1308,use the former one.
# No matching task for timestamp 1309,use the former one.
# No matching task for timestamp 1361,use the former one.
# No matching task for timestamp 1362,use the former one.
# No matching task for timestamp 1363,use the former one.
# No matching task for timestamp 1364,use the former one.
# No matching task for timestamp 1365,use the former one.
# No matching task for timestamp 1366,use the former one.
# No matching task for timestamp 1367,use the former one.
# No matching task for timestamp 1368,use the former one.
# No matching task for timestamp 1369,use the former one.
# No matching task for timestamp 1370,use the former one.
# No matching task for timestamp 1370,use the former one.
# No matching task for timestamp 1371,use the former one.
# No matching task for timestamp 1372,use the former one.
# No matching task for timestamp 1373,use the former one.
# No matching task for timestamp 1374,use the former one.
# No matching task for timestamp 1375,use the former one.
# No matching task for timestamp 1376,use the former one.
# No matching task for timestamp 1377,use the former one.
# No matching task for timestamp 1378,use the former one.
# No matching task for timestamp 1379,use the former one.
# No matching task for timestamp 1380,use the former one.
# No matching task for timestamp 1381,use the former one.
# No matching task for timestamp 1382,use the former one.
# No matching task for timestamp 1383,use the former one.
# No matching task for timestamp 1384,use the former one.
# No matching task for timestamp 1385,use the former one.
# No matching task for timestamp 1386,use the former one.
# No matching task for timestamp 1387,use the former one.
# No matching task for timestamp 1672,use the former one.
# No matching task for timestamp 1673,use the former one.
# No matching task for timestamp 1674,use the former one.
# No matching task for timestamp 1675,use the former one.
# No matching task for timestamp 1676,use the former one.
# No matching task for timestamp 1677,use the former one.
# No matching task for timestamp 1678,use the former one.
# No matching task for timestamp 1870,use the former one.
# No matching task for timestamp 1871,use the former one.
# No matching task for timestamp 1872,use the former one.
# No matching task for timestamp 1873,use the former one.
# No matching task for timestamp 1874,use the former one.
# No matching task for timestamp 1875,use the former one.
# No matching task for timestamp 1876,use the former one.
# No matching task for timestamp 1877,use the former one.
# No matching task for timestamp 1877,use the former one.
# No matching task for timestamp 1878,use the former one.
# No matching task for timestamp 1879,use the former one.
# No matching task for timestamp 1880,use the former one.
# No matching task for timestamp 1881,use the former one.
# No matching task for timestamp 1882,use the former one.
# No matching task for timestamp 1883,use the former one.
# No matching task for timestamp 1884,use the former one.
# No matching task for timestamp 1885,use the former one.
# No matching task for timestamp 1886,use the former one.
# No matching task for timestamp 1887,use the former one.
# No matching task for timestamp 1888,use the former one.
# No matching task for timestamp 1889,use the former one.
# No matching task for timestamp 1890,use the former one.
# No matching task for timestamp 1891,use the former one.
# No matching task for timestamp 1892,use the former one.
# No matching task for timestamp 1893,use the former one.
# No matching task for timestamp 1894,use the former one.
# No matching task for timestamp 27100,use the former one.
# No matching task for timestamp 27101,use the former one.
# No matching task for timestamp 27102,use the former one.
# No matching task for timestamp 27103,use the former one.
# No matching task for timestamp 27104,use the former one.
# No matching task for timestamp 27105,use the former one.
# No matching task for timestamp 27106,use the former one.
# No matching task for timestamp 27107,use the former one.
# No matching task for timestamp 27108,use the former one.
# No matching task for timestamp 27109,use the former one.
# No matching task for timestamp 27588,use the former one.
# No matching task for timestamp 27589,use the former one.
# No matching task for timestamp 27590,use the former one.
# No matching task for timestamp 27591,use the former one.
# No matching task for timestamp 27592,use the former one.
# No matching task for timestamp 27593,use the former one.
# No matching task for timestamp 27594,use the former one.
# No matching task for timestamp 27595,use the former one.
# No matching task for timestamp 27596,use the former one.
# No matching task for timestamp 27597,use the former one.
# No matching task for timestamp 27598,use the former one.
# No matching task for timestamp 27599,use the former one.
# No matching task for timestamp 27776,use the former one.
# No matching task for timestamp 27777,use the former one.
# No matching task for timestamp 27778,use the former one.
# No matching task for timestamp 27779,use the former one.
# No matching task for timestamp 27780,use the former one.
# No matching task for timestamp 27781,use the former one.
# No matching task for timestamp 27782,use the former one.
# No matching task for timestamp 27783,use the former one.
# No matching task for timestamp 27784,use the former one.
# No matching task for timestamp 28099,use the former one.
# No matching task for timestamp 28100,use the former one.
# No matching task for timestamp 28101,use the former one.
# No matching task for timestamp 28102,use the former one.
# No matching task for timestamp 28103,use the former one.
# No matching task for timestamp 28104,use the former one.
# No matching task for timestamp 28105,use the former one.
# No matching task for timestamp 28106,use the former one.
# No matching task for timestamp 28107,use the former one.
# No matching task for timestamp 28108,use the former one.
# No matching task for timestamp 28109,use the former one.
# No matching task for timestamp 28224,use the former one.
# No matching task for timestamp 28225,use the former one.
# No matching task for timestamp 28226,use the former one.
# No matching task for timestamp 29910,use the former one.
# No matching task for timestamp 29911,use the former one.
# No matching task for timestamp 29912,use the former one.
# No matching task for timestamp 29913,use the former one.
# No matching task for timestamp 29914,use the former one.
# No matching task for timestamp 29915,use the former one.
# No matching task for timestamp 29916,use the former one.
# No matching task for timestamp 29917,use the former one.
# No matching task for timestamp 29918,use the former one.
# No matching task for timestamp 29919,use the former one.
# No matching task for timestamp 29920,use the former one.
# No matching task for timestamp 29921,use the former one.
# No matching task for timestamp 29922,use the former one.
# No matching task for timestamp 29923,use the former one.
# No matching task for timestamp 29924,use the former one.
# No matching task for timestamp 29925,use the former one.
# No matching task for timestamp 29929,use the former one.
# No matching task for timestamp 29930,use the former one.
# No matching task for timestamp 29931,use the former one.
# No matching task for timestamp 29931,use the former one.
# No matching task for timestamp 29932,use the former one.
# No matching task for timestamp 29933,use the former one.
# No matching task for timestamp 29934,use the former one.
# No matching task for timestamp 29935,use the former one.
# No matching task for timestamp 29936,use the former one.
# No matching task for timestamp 29937,use the former one.
# No matching task for timestamp 29938,use the former one.
# No matching task for timestamp 29939,use the former one.
# No matching task for timestamp 29940,use the former one.
# No matching task for timestamp 29941,use the former one.
# No matching task for timestamp 29942,use the former one.
# No matching task for timestamp 29943,use the former one.
# No matching task for timestamp 29944,use the former one.
# No matching task for timestamp 29945,use the former one.
# No matching task for timestamp 29946,use the former one.
# No matching task for timestamp 29947,use the former one.
# No matching task for timestamp 29948,use the former one.
# No matching task for timestamp 29949,use the former one.
# No matching task for timestamp 29950,use the former one.
# No matching task for timestamp 29951,use the former one.
# No matching task for timestamp 29952,use the former one.
# No matching task for timestamp 29953,use the former one.
# No matching task for timestamp 29954,use the former one.
# No matching task for timestamp 29955,use the former one.
# No matching task for timestamp 29956,use the former one.
# No matching task for timestamp 29957,use the former one.
# No matching task for timestamp 29958,use the former one.
# No matching task for timestamp 29959,use the former one.
# No matching task for timestamp 29960,use the former one.
# No matching task for timestamp 29961,use the former one.
# No matching task for timestamp 29962,use the former one.
# No matching task for timestamp 29963,use the former one.
# No matching task for timestamp 29964,use the former one.
# No matching task for timestamp 29965,use the former one.
# No matching task for timestamp 29966,use the former one.
# No matching task for timestamp 29967,use the former one.
# No matching task for timestamp 29968,use the former one.
# No matching task for timestamp 29969,use the former one.
# No matching task for timestamp 29970,use the former one.
# No matching task for timestamp 29971,use the former one.
# No matching task for timestamp 29972,use the former one.
# No matching task for timestamp 29973,use the former one.
# No matching task for timestamp 29974,use the former one.
# No matching task for timestamp 29975,use the former one.
# No matching task for timestamp 29976,use the former one.
# No matching task for timestamp 29976,use the former one.
# No matching task for timestamp 29977,use the former one.
# No matching task for timestamp 29978,use the former one.
# No matching task for timestamp 29979,use the former one.
# No matching task for timestamp 29980,use the former one.
# No matching task for timestamp 30392,use the former one.
# No matching task for timestamp 30393,use the former one.
# No matching task for timestamp 30394,use the former one.
# No matching task for timestamp 30395,use the former one.
# No matching task for timestamp 30396,use the former one.
# No matching task for timestamp 30397,use the former one.
# No matching task for timestamp 30398,use the former one.
# No matching task for timestamp 30399,use the former one.
# No matching task for timestamp 30400,use the former one.
# No matching task for timestamp 30401,use the former one.
# No matching task for timestamp 30402,use the former one.
# No matching task for timestamp 30403,use the former one.
# No matching task for timestamp 30404,use the former one.
# No matching task for timestamp 30405,use the former one.
# No matching task for timestamp 30406,use the former one.
# No matching task for timestamp 30407,use the former one.
# No matching task for timestamp 30408,use the former one.
# No matching task for timestamp 30409,use the former one.
# No matching task for timestamp 30410,use the former one.
# No matching task for timestamp 30411,use the former one.
# No matching task for timestamp 30412,use the former one.
# No matching task for timestamp 30413,use the former one.
# No matching task for timestamp 30414,use the former one.
# No matching task for timestamp 30415,use the former one.
# No matching task for timestamp 30416,use the former one.
# No matching task for timestamp 30416,use the former one.
# No matching task for timestamp 30417,use the former one.
# No matching task for timestamp 30418,use the former one.
# No matching task for timestamp 30419,use the former one.
# No matching task for timestamp 30420,use the former one.
# No matching task for timestamp 30421,use the former one.
# No matching task for timestamp 30422,use the former one.
# No matching task for timestamp 30423,use the former one.
# No matching task for timestamp 30424,use the former one.
# No matching task for timestamp 30425,use the former one.
# No matching task for timestamp 30426,use the former one.
# No matching task for timestamp 31734,use the former one.
# No matching task for timestamp 31735,use the former one.
# No matching task for timestamp 31736,use the former one.
# No matching task for timestamp 31737,use the former one.
# No matching task for timestamp 31738,use the former one.
# No matching task for timestamp 31739,use the former one.
# No matching task for timestamp 31740,use the former one.
# No matching task for timestamp 31741,use the former one.
# No matching task for timestamp 31742,use the former one.
# No matching task for timestamp 31743,use the former one.
# No matching task for timestamp 31744,use the former one.
# No matching task for timestamp 31745,use the former one.
# No matching task for timestamp 32773,use the former one.
# No matching task for timestamp 32774,use the former one.
# No matching task for timestamp 32775,use the former one.
# No matching task for timestamp 32776,use the former one.
# No matching task for timestamp 32777,use the former one.
# No matching task for timestamp 32778,use the former one.
# No matching task for timestamp 32779,use the former one.
# No matching task for timestamp 32780,use the former one.
# No matching task for timestamp 32781,use the former one.
# No matching task for timestamp 32782,use the former one.
# No matching task for timestamp 32783,use the former one.
# No matching task for timestamp 32784,use the former one.
# No matching task for timestamp 32785,use the former one.
# No matching task for timestamp 32786,use the former one.
# No matching task for timestamp 32787,use the former one.
# No matching task for timestamp 32788,use the former one.
# No matching task for timestamp 32789,use the former one.
# No matching task for timestamp 32790,use the former one.
# No matching task for timestamp 32791,use the former one.
# No matching task for timestamp 32792,use the former one.
# No matching task for timestamp 32833,use the former one.
# No matching task for timestamp 32834,use the former one.
# No matching task for timestamp 32835,use the former one.
# No matching task for timestamp 32836,use the former one.
# No matching task for timestamp 32837,use the former one.
# No matching task for timestamp 32838,use the former one.
# No matching task for timestamp 32838,use the former one.
# No matching task for timestamp 32839,use the former one.
# No matching task for timestamp 32840,use the former one.
# No matching task for timestamp 32841,use the former one.
# No matching task for timestamp 32842,use the former one.
# No matching task for timestamp 32843,use the former one.
# No matching task for timestamp 32844,use the former one.
# No matching task for timestamp 32845,use the former one.
# No matching task for timestamp 32846,use the former one.
# No matching task for timestamp 32847,use the former one.
# No matching task for timestamp 32848,use the former one.
# No matching task for timestamp 32849,use the former one.
# No matching task for timestamp 32850,use the former one.
# No matching task for timestamp 32851,use the former one.
# No matching task for timestamp 32852,use the former one.
# No matching task for timestamp 32853,use the former one.
# No matching task for timestamp 32854,use the former one.
# No matching task for timestamp 32855,use the former one.
# No matching task for timestamp 32856,use the former one.
# No matching task for timestamp 32857,use the former one.
# No matching task for timestamp 32858,use the former one.
# No matching task for timestamp 32859,use the former one.
# No matching task for timestamp 32860,use the former one.
# No matching task for timestamp 32861,use the former one.
# No matching task for timestamp 32862,use the former one.
# No matching task for timestamp 32863,use the former one.
# No matching task for timestamp 32864,use the former one.
# No matching task for timestamp 32865,use the former one.
# No matching task for timestamp 32866,use the former one.
# No matching task for timestamp 32867,use the former one.
# No matching task for timestamp 32868,use the former one.
# No matching task for timestamp 32917,use the former one.
# No matching task for timestamp 32918,use the former one.
# No matching task for timestamp 32919,use the former one.
# No matching task for timestamp 32920,use the former one.
# No matching task for timestamp 32921,use the former one.
# No matching task for timestamp 32922,use the former one.
# No matching task for timestamp 32923,use the former one.
# No matching task for timestamp 32924,use the former one.
# No matching task for timestamp 32925,use the former one.
# No matching task for timestamp 32926,use the former one.
# No matching task for timestamp 32927,use the former one.
# No matching task for timestamp 32928,use the former one.
# No matching task for timestamp 32929,use the former one.
# No matching task for timestamp 32930,use the former one.
# No matching task for timestamp 32931,use the former one.
# No matching task for timestamp 32932,use the former one.
# No matching task for timestamp 32933,use the former one.
# No matching task for timestamp 32934,use the former one.
# No matching task for timestamp 32935,use the former one.
# No matching task for timestamp 32936,use the former one.
# No matching task for timestamp 32937,use the former one.
# No matching task for timestamp 32938,use the former one.
# No matching task for timestamp 32988,use the former one.
# No matching task for timestamp 32989,use the former one.
# No matching task for timestamp 32990,use the former one.
# No matching task for timestamp 32991,use the former one.
# No matching task for timestamp 32992,use the former one.
# No matching task for timestamp 32993,use the former one.
# No matching task for timestamp 32994,use the former one.
# No matching task for timestamp 32995,use the former one.
# No matching task for timestamp 27081,use the former one.
# No matching task for timestamp 27082,use the former one.
# No matching task for timestamp 27083,use the former one.
# No matching task for timestamp 27084,use the former one.
# No matching task for timestamp 27085,use the former one.
# No matching task for timestamp 27086,use the former one.
# No matching task for timestamp 27087,use the former one.
# No matching task for timestamp 27088,use the former one.
# No matching task for timestamp 1116,use the former one.
# No matching task for timestamp 1117,use the former one.
# No matching task for timestamp 1118,use the former one.
# No matching task for timestamp 1540,use the former one.
# No matching task for timestamp 1541,use the former one.
# No matching task for timestamp 1542,use the former one.
# No matching task for timestamp 1543,use the former one.
# No matching task for timestamp 1544,use the former one.
# No matching task for timestamp 1545,use the former one.
# No matching task for timestamp 1546,use the former one.
# No matching task for timestamp 1547,use the former one.
# No matching task for timestamp 1548,use the former one.
# No matching task for timestamp 1549,use the former one.
# No matching task for timestamp 1153,use the former one.
# No matching task for timestamp 1154,use the former one.
# No matching task for timestamp 1155,use the former one.
# No matching task for timestamp 1156,use the former one.
# No matching task for timestamp 1157,use the former one.
# No matching task for timestamp 1158,use the former one.
# No matching task for timestamp 1159,use the former one.
# No matching task for timestamp 1160,use the former one.
# No matching task for timestamp 1161,use the former one.
# No matching task for timestamp 1162,use the former one.
# No matching task for timestamp 1248,use the former one.
# No matching task for timestamp 1249,use the former one.
# No matching task for timestamp 1250,use the former one.
# No matching task for timestamp 1251,use the former one.
# No matching task for timestamp 1252,use the former one.
# No matching task for timestamp 1253,use the former one.
# No matching task for timestamp 1254,use the former one.
# No matching task for timestamp 1255,use the former one.
# No matching task for timestamp 2975,use the former one.
# No matching task for timestamp 2976,use the former one.
# No matching task for timestamp 2977,use the former one.
# No matching task for timestamp 2978,use the former one.
# No matching task for timestamp 2979,use the former one.
# No matching task for timestamp 2980,use the former one.
# No matching task for timestamp 2981,use the former one.
# No matching task for timestamp 2982,use the former one.
# No matching task for timestamp 2983,use the former one.
# No matching task for timestamp 2984,use the former one.
# No matching task for timestamp 870,use the former one.
# No matching task for timestamp 871,use the former one.
# No matching task for timestamp 872,use the former one.
# No matching task for timestamp 873,use the former one.
# No matching task for timestamp 874,use the former one.
# No matching task for timestamp 875,use the former one.
# No matching task for timestamp 876,use the former one.
# No matching task for timestamp 877,use the former one.
# No matching task for timestamp 967,use the former one.
# No matching task for timestamp 968,use the former one.
# No matching task for timestamp 969,use the former one.
# No matching task for timestamp 970,use the former one.
# No matching task for timestamp 971,use the former one.
# No matching task for timestamp 972,use the former one.
# No matching task for timestamp 973,use the former one.
#          u    v  timestamp  state_label  feature
# 198891  12  100        106            1  0.22588
# 198892  12  100        107            1  0.22588
# 198893  12  100        108            1  0.22588
# 198894  12  100        109            1  0.22588
# 198895  12  100        110            1  0.22588
# ...     ..  ...        ...          ...      ...
# 68360    4  100      33081            1  0.22588
# 68361    4  100      33082            1  0.22588
# 68362    4  100      33083            1  0.22588
# 68363    4  100      33084            1  0.22588
# 68364    4  100      33085            1  0.22588
#
# [287644 rows x 5 columns]
# save the graph data of all participants to data4train/graph_data_combined.csv
# save the combined nodes and features dictionary to dict/nodes.txt and dict/features.txt
# Time cost: 1067.8795053958893 seconds
# done
